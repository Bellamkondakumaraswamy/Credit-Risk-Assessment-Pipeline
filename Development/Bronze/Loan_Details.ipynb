-- %%
%python
df= spark.read.parquet(

    "abfss://datasets@creditp2adls.dfs.core.windows.net/parquet_files/loan_details.parquet"
)

display(df)

-- %%
CREATE TABLE credit_analysis_catalog.bronze.loan_details
USING PARQUET
LOCATION 'abfss://datasets@creditp2adls.dfs.core.windows.net/parquet_files/loan_details.parquet';

-- %%
select * from credit_analysis_catalog.bronze.loan_details;
