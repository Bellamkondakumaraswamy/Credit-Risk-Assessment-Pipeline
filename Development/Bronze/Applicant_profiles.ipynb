-- %%
show external locations;

-- %%
%python
df= spark.read.parquet(

    "abfss://datasets@creditp2adls.dfs.core.windows.net/parquet_files/applicant_profiles.parquet"
)

display(df)

-- %%
    %sql
    CREATE TABLE credit_analysis_catalog.bronze.applicant_profiles
    USING parquet
    LOCATION "abfss://datasets@creditp2adls.dfs.core.windows.net/parquet_files/applicant_profiles.parquet";

-- %%
select *from credit_analysis_catalog.bronze.applicant_profiles;
