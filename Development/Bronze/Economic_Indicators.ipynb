-- %%
%python
df= spark.read.parquet(

    "abfss://datasets@creditp2adls.dfs.core.windows.net/parquet_files/economic_indicators.parquet"
)

display(df)

-- %%
%sql

CREATE TABLE credit_analysis_catalog.bronze.economic_indicators
USING PARQUET
LOCATION 'abfss://datasets@creditp2adls.dfs.core.windows.net/parquet_files/economic_indicators.parquet';

-- %%
select * from credit_analysis_catalog.bronze.economic_indicators;
