-- %%
%python
df= spark.read.parquet(

    "abfss://datasets@creditp2adls.dfs.core.windows.net/parquet_files/credit_history.parquet"
)

display(df)

-- %%
%sql

CREATE TABLE credit_analysis_catalog.bronze.credit_history
USING PARQUET
LOCATION 'abfss://datasets@creditp2adls.dfs.core.windows.net/parquet_files/credit_history.parquet';

-- %%
select * from credit_analysis_catalog.bronze.credit_history;
