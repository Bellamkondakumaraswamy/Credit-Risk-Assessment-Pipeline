-- %%
%python
df= spark.read.parquet(

    "abfss://datasets@creditp2adls.dfs.core.windows.net/parquet_files/credit_applications .parquet"
)

display(df)

-- %%
%sql
CREATE TABLE credit_analysis_catalog.bronze.credit_application
USING parquet
LOCATION "abfss://datasets@creditp2adls.dfs.core.windows.net/parquet_files/credit_applications .parquet";

-- %%
select * from credit_analysis_catalog.bronze.credit_application;
